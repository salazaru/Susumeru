# %%
import numpy as np 
import pandas as pd 

import seaborn as sns
import matplotlib.pyplot as plt

import geopandas as gpd
import pycountry
import pygal.maps
import pygal_maps_world.maps
from pygal.style import Style

# %%
df_raw = pd.read_csv('user_mal.csv')
df_raw = df_raw.dropna()
df_raw.head(5)
# 46358130 rows × 3 columns
# Out:
#    username  anime_id  my_score
# 0  karthiga        21       9.0
# 1  karthiga        59       7.0
# 2  karthiga        74       7.0
# 3  karthiga       120       7.0
# 4  karthiga       178       7.0

# %%
df_anime = pd.read_csv('anime.csv')
df_anime = df_anime.dropna()
df_anime.head(5)
# Out:
#    anime_id                title           status  \
# 0     11013        Inu x Boku SS  Finished Airing
# 1      2104     Seto no Hanayome  Finished Airing
# 2      5262   Shugo Chara!! Doki  Finished Airing
# 3       721        Princess Tutu  Finished Airing
# 4     12365  Bakuman. 3rd Season  Finished Airing
#
#                    aired_string  score  scored_by    rank  popularity  \
# 0  Jan 13, 2012 to Mar 30, 2012   7.63   139250.0  1274.0       231.0
# 1    Apr 2, 2007 to Oct 1, 2007   7.89    91206.0   727.0       366.0
# 2   Oct 4, 2008 to Sep 25, 2009   7.55    37129.0  1508.0      1173.0
# 3  Aug 16, 2002 to May 23, 2003   8.21    36501.0   307.0       916.0
# 4   Oct 6, 2012 to Mar 30, 2013   8.67   107767.0    50.0       426.0
#
#     members                                     genre
# 0  283882.0    Comedy, Supernatural, Romance, Shounen
# 1  204003.0  Comedy, Parody, Romance, School, Shounen
# 2   70127.0             Comedy, Magic, School, Shoujo
# 3   93312.0    Comedy, Drama, Magic, Romance, Fantasy
# 4  182765.0           Comedy, Drama, Romance, Shounen

# %%
df_country = pd.read_csv('user_country_age.csv')
df_country = df_country.dropna()
df_country.head(5)
# Out:
#            username  user_id  gender        country  age
# 0          karthiga  2255153  Female          India   30
# 1  RedvelvetDaisuki  1897606  Female    Philippines   26
# 2         Damonashu    37326    Male  United states   29
# 3             bskai   228342    Male         Mexico   30
# 4    terune_uzumaki   327311  Female       Malaysia   22

# %%
# use inner join df_anime and df_raw on 'anime_id'
merged_inner = pd.merge(left=df_anime, right=df_raw, left_on='anime_id', right_on='anime_id')
# merged_inner.shape
merged_inner.head()
## spend 1 minutes
# Out:
#    anime_id          title           status                  aired_string  \
# 0     11013  Inu x Boku SS  Finished Airing  Jan 13, 2012 to Mar 30, 2012
# 1     11013  Inu x Boku SS  Finished Airing  Jan 13, 2012 to Mar 30, 2012
# 2     11013  Inu x Boku SS  Finished Airing  Jan 13, 2012 to Mar 30, 2012
# 3     11013  Inu x Boku SS  Finished Airing  Jan 13, 2012 to Mar 30, 2012
# 4     11013  Inu x Boku SS  Finished Airing  Jan 13, 2012 to Mar 30, 2012
#
#    score  scored_by    rank  popularity   members  \
# 0   7.63   139250.0  1274.0       231.0  283882.0
# 1   7.63   139250.0  1274.0       231.0  283882.0
# 2   7.63   139250.0  1274.0       231.0  283882.0
# 3   7.63   139250.0  1274.0       231.0  283882.0
# 4   7.63   139250.0  1274.0       231.0  283882.0
#
#                                     genre       username  my_score
# 0  Comedy, Supernatural, Romance, Shounen       karthiga       8.0
# 1  Comedy, Supernatural, Romance, Shounen    thetreedude       7.0
# 2  Comedy, Supernatural, Romance, Shounen  MistButterfly       7.0
# 3  Comedy, Supernatural, Romance, Shounen      iLLMaTiCc       6.0
# 4  Comedy, Supernatural, Romance, Shounen       helenply       9.0

# %%
#  use inner join merged_inner and df_country on 'username'

final_merge = pd.merge(left=merged_inner, right=df_country, left_on='username', right_on='username')
final_merge.head(5)
# Out:
#    anime_id                title           status  \
# 0     11013        Inu x Boku SS  Finished Airing
# 1      2104     Seto no Hanayome  Finished Airing
# 2      5262   Shugo Chara!! Doki  Finished Airing
# 3       721        Princess Tutu  Finished Airing
# 4     12365  Bakuman. 3rd Season  Finished Airing
#
#                    aired_string  score  scored_by    rank  popularity  \
# 0  Jan 13, 2012 to Mar 30, 2012   7.63   139250.0  1274.0       231.0
# 1    Apr 2, 2007 to Oct 1, 2007   7.89    91206.0   727.0       366.0
# 2   Oct 4, 2008 to Sep 25, 2009   7.55    37129.0  1508.0      1173.0
# 3  Aug 16, 2002 to May 23, 2003   8.21    36501.0   307.0       916.0
# 4   Oct 6, 2012 to Mar 30, 2013   8.67   107767.0    50.0       426.0
#
#     members                                     genre  username  my_score  \
# 0  283882.0    Comedy, Supernatural, Romance, Shounen  karthiga       8.0
# 1  204003.0  Comedy, Parody, Romance, School, Shounen  karthiga       7.0
# 2   70127.0             Comedy, Magic, School, Shoujo  karthiga       7.0
# 3   93312.0    Comedy, Drama, Magic, Romance, Fantasy  karthiga       7.0
# 4  182765.0           Comedy, Drama, Romance, Shounen  karthiga       8.0
#
#    user_id  gender country  age
# 0  2255153  Female   India   30
# 1  2255153  Female   India   30
# 2  2255153  Female   India   30
# 3  2255153  Female   India   30
# 4  2255153  Female   India   30

# %% [markdown]
# ### Basic introduction for the merged dataset

# %%
# Number of countries in the dataset
country = set(final_merge['country'])
print(len(country))
# Out:
# 179

# %%
# Number of unique animes in the dataset
animes = set(final_merge['title'])
print(len(animes))
# Out:
# 11941

# %% [markdown]
# ### Get most viewed anime and averaged score from users in dataset by country

# %%
def get_most_viewed_anime_from_country(country, final_merge):
    country_df       = final_merge[final_merge.country.str.contains(country)]
    most_viewed_count = country_df["title"].value_counts()
    result={}
    most_viewed_anime               = most_viewed_count.keys()[0]
    most_viewed_anime_average_score = round(country_df[country_df.title.isin([country_df["title"].value_counts().keys()[0]])].my_score.mean(), 2)
    result[most_viewed_anime]       = most_viewed_anime_average_score
    return result

# %%
get_most_viewed_anime_from_country("India", final_merge)
# Out:
# {'Death Note': 9.14}

# %%
# Since it is a large dataset, it takes 20 miniutes to run

most_viewed_by_country = {}
for ct in list(country):
    most_viewed_by_country[ct] = get_most_viewed_anime_from_country(ct ,final_merge)
### Takes 20 mins to get the result

# %%
most_viewed_by_country
# Out:
# {'Cayman islands': {'Denpa Onna to Seishun Otoko': 8.5},
#  'Qatar': {'Death Note': 9.53},
#  'Hungary': {'Death Note': 8.7},
#  'Macedonia': {'Death Note': 9.12},
#  'Saint lucia': {'Fairy Tail': 9.5},
#  'Ecuador': {'Death Note': 8.88},
#  'Barbados': {'Vampire Knight': 7.25},
#  'Australia': {'Death Note': 8.59},
#  'Georgia': {'Death Note': 8.74},
#  'Bahrain': {'Death Note': 9.25},
#  'Nigeria': {'Bleach': 7.56},
#  'Slovakia': {'Death Note': 8.7},
#  'Estonia': {'Death Note': 8.85},
#  'Albania': {'Death Note': 9.19},
#  'Maldives': {'One Piece': 8.33},
#  'Jamaica': {'Naruto': 8.07},
#  'Gabon': {'Chobits': 7.0},
#  'Mali': {'Death Note': 9.0},
#  'Indonesia': {'Sword Art Online': 8.23},
#  'Costa rica': {'Death Note': 8.89},
#  'Thailand': {'Toradora!': 8.6},
#  'Tanzania': {'Boku wa Tomodachi ga Sukunai': 7.0},
#  'Malaysia': {'Angel Beats!': 8.73},
#  'Brazil': {'Death Note': 8.75},
#  'Liberia': {'Fullmetal Alchemist': 9.0},
#  'Guatemala': {'Death Note': 8.75},
#  'Reunion': {'Dragon Ball Z Movie 14: Kami to Kami': 10.0},
#  'China': {'Code Geass: Hangyaku no Lelouch R2': 9.02},
#  'Argentina': {'Death Note': 8.58},
#  'Slovenia': {'Death Note': 8.93},
#  'Morocco': {'Death Note': 9.42},
#  'Bolivia': {'Death Note': 8.21},
#  'Aruba': {'Fairy Tail': 8.14},
#  'Uzbekistan': {'Death Note': 7.86},
#  'Spain': {'Death Note': 8.54},
#  'Korea, south': {'Death Note': 8.44},
#  'Jordan': {'Death Note': 8.74},
#  'Azerbaijan': {'Death Note': 8.88},
#  'Djibouti': {'Psycho-Pass': 8.0},
#  'French polynesia': {'Break Blade': 4.0},
#  'Denmark': {'Death Note': 8.61},
#  'Sweden': {'Death Note': 8.56},
#  'Faroe islands': {'Naruto': 7.6},
#  'Kazakhstan': {'Death Note': 8.81},
#  'Guam': {'Mayo Chiki!': 7.62},
#  'Algeria': {'Shingeki no Kyojin': 9.26},
#  'Isle of man': {'Fullmetal Alchemist': 7.8},
#  'Cambodia': {'Shingeki no Kyojin': 9.2},
#  'Finland': {'Death Note': 8.56},
#  'San marino': {'JoJo no Kimyou na Bouken: Stardust Crusaders 2nd Season': 8.0},
#  'Vietnam': {'Angel Beats!': 8.59},
#  'Senegal': {'High School DxD': 7.0},
#  'Sierra leone': {'Tokyo Mew Mew': 6.0},
#  'Iceland': {'Death Note': 8.8},
#  'Andorra': {'Death Note': 8.75},
#  'Iran': {'Death Note': 8.59},
#  'Malta': {'Death Note': 8.83},
#  'New zealand': {'Death Note': 8.52},
#  'United arab emirates': {'Death Note': 8.91},
#  'Marshall islands': {'Yuru Camp△ Specials': 8.0},
#  'Canada': {'Death Note': 8.61},
#  'Russia': {'Death Note': 8.28},
#  'Dominican republic': {'Death Note': 9.19},
#  'Angola': {'Elfen Lied': 8.2},
#  'Somalia': {'Zoids': 10.0},
#  'Japan': {'Death Note': 8.72},
#  'Bahamas, the': {'Naruto': 8.75},
#  'Egypt': {'Death Note': 9.18},
#  'Venezuela': {'Death Note': 8.69},
#  'Madagascar': {'Death Note': 8.67},
#  'Suriname': {'Naruto': 8.75},
#  'Netherlands': {'Death Note': 8.76},
#  'Togo': {'Majo no Takkyuubin': 1.0},
#  'Hong kong': {'Angel Beats!': 8.8},
#  'Bermuda': {'Minami-ke': 8.0},
#  'Cuba': {'Neon Genesis Evangelion': 7.67},
#  'Martinique': {'Aldnoah.Zero': 7.5},
#  'Montenegro': {'Death Note': 9.13},
#  'Italy': {'Death Note': 8.37},
#  'Ukraine': {'Death Note': 8.63},
#  'Paraguay': {'Death Note': 9.0},
#  'Samoa': {'Busou Renkin': 6.0},
#  'Philippines': {'Toradora!': 8.85},
#  'Puerto rico': {'Death Note': 8.98},
#  'Saint vincent and the grenadines': {'Boku no Hero Academia 2nd Season': 9.0},
#  'Fiji': {'Sword Art Online': 7.38},
#  'Mongolia': {'Death Note': 9.0},
#  'United kingdom': {'Death Note': 8.7},
#  'Mozambique': {'High School DxD': 5.5},
#  'Namibia': {'Chobits': 7.0},
#  'Peru': {'Death Note': 8.85},
#  'Cyprus': {'Death Note': 9.53},
#  'Chile': {'Death Note': 8.39},
#  'Bangladesh': {'Death Note': 9.18},
#  'Croatia': {'Death Note': 9.02},
#  'Belgium': {'Death Note': 8.66},
#  'Moldova': {'Death Note': 8.95},
#  'Timor-leste': {'Bakuten Shoot Beyblade 2002': 7.0},
#  'Syria': {'Death Note': 9.26},
#  'Trinidad and tobago': {'Naruto': 7.36},
#  'Luxembourg': {'Elfen Lied': 7.71},
#  'India': {'Death Note': 9.14},
#  'Portugal': {'Death Note': 8.92},
#  'Turkey': {'Death Note': 9.0},
#  'Saudi arabia': {'Death Note': 9.22},
#  'Ghana': {'Death Note': 7.75},
#  'Lebanon': {'Death Note': 8.79},
#  'Taiwan': {'Code Geass: Hangyaku no Lelouch': 9.12},
#  'Mauritania': {'Fullmetal Alchemist': 9.0},
#  'Czechia': {'Death Note': 8.73},
#  'Niger': {'Bleach': 7.56},
#  'Latvia': {'Death Note': 9.06},
#  'Pakistan': {'Death Note': 9.14},
#  'Tunisia': {'Death Note': 9.25},
#  'Lithuania': {'Death Note': 9.19},
#  'Kyrgyzstan': {'Minami-ke': 7.0},
#  'Romania': {'Death Note': 9.28},
#  'Belize': {'Shingeki no Kyojin': 9.4},
#  'Kiribati': {'JoJo no Kimyou na Bouken: Stardust Crusaders 2nd Season': 9.0},
#  'Colombia': {'Death Note': 8.85},
#  'South africa': {'Death Note': 8.63},
#  'Jersey': {'Suzumiya Haruhi no Yuuutsu': 8.75},
#  'Curaçao': {'Bleach': 10.0},
#  'Israel': {'Death Note': 8.87},
#  'Austria': {'Death Note': 8.91},
#  'Burkina faso': {'Bleach': 6.67},
#  'Iraq': {'Death Note': 8.95},
#  'French guiana': {'Boku no Hero Academia 2nd Season: Hero Note': 7.0},
#  'Monaco': {"Wolf's Rain": 8.0},
#  'Honduras': {'Death Note': 9.13},
#  'Yemen': {'Baka to Test to Shoukanjuu': 7.86},
#  'Switzerland': {'Death Note': 8.53},
#  'Brunei': {'Toradora!': 8.53},
#  'Vatican city': {'High School DxD': 7.0},
#  'Korea, north': {'Death Note': 6.75},
#  'Belarus': {'Death Note': 8.5},
#  'Greece': {'Death Note': 8.95},
#  'Panama': {'Death Note': 9.19},
#  'Ireland': {'Death Note': 8.64},
#  'Serbia': {'Death Note': 8.94},
#  'Guyana': {'Sword Art Online': 7.14},
#  'Kenya': {'Bleach': 8.33},
#  'Norway': {'Death Note': 8.71},
#  'Poland': {'Death Note': 8.85},
#  'Burma': {'Clannad': 8.4},
#  'Sri lanka': {'Death Note': 8.75},
#  'Zimbabwe': {'Campione!: Matsurowanu Kamigami to Kamigoroshi no Maou': 6.33},
#  'Haiti': {'Sen to Chihiro no Kamikakushi': 7.5},
#  'Mauritius': {'Death Note': 9.42},
#  'France': {'Death Note': 8.46},
#  'Côte d’ivoire': {'Magi: Sinbad no Bouken (TV)': 8.0},
#  'Kosovo': {'Orange': 7.0},
#  'Nicaragua': {'Death Note': 9.1},
#  'South sudan': {'Kiseijuu: Sei no Kakuritsu': 9.0},
#  'Greenland': {'Baka to Test to Shoukanjuu': 7.43},
#  'Bulgaria': {'Death Note': 9.24},
#  'Sudan': {'Shingeki no Kyojin': 8.0},
#  'Mexico': {'Death Note': 8.84},
#  'Singapore': {'Toradora!': 8.49},
#  'Uruguay': {'Death Note': 8.6},
#  'Libya': {'Death Note': 9.42},
#  'Uganda': {'Sword Art Online': 6.5},
#  'Macau': {'Shingeki no Kyojin': 8.75},
#  'Nepal': {'Sword Art Online': 8.23},
#  'Liechtenstein': {'JoJo no Kimyou na Bouken: Stardust Crusaders 2nd Season': 10.0},
#  'Armenia': {'Sen to Chihiro no Kamikakushi': 8.17},
#  'Bosnia and herzegovina': {'Death Note': 9.22},
#  'El salvador': {'Death Note': 9.0},
#  'Grenada': {'Bleach': 9.5},
#  'Bhutan': {'Naruto': 10.0},
#  'Solomon islands': {'Tokyo Mew Mew': 6.0},
#  'Dominica': {'Death Note': 9.24},
#  'Swaziland': {'Chobits': 10.0},
#  'Germany': {'Death Note': 8.85},
#  'Laos': {'Hyouka: Motsubeki Mono wa': 8.5},
#  'Botswana': {'Naruto': 8.0},
#  'Oman': {'Death Note': 9.43},
#  'Kuwait': {'Death Note': 9.18},
#  'United states': {'Death Note': 8.55}}

# %%
# import pycountry
input_countries = list(most_viewed_by_country.keys()) 

countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_2

Coun_codes = [countries.get(country, country).lower() for country in input_countries]

# print(Coun_codes)
most_viewed_by_country1 = most_viewed_by_country
for i in range(len(Coun_codes)):
    most_viewed_by_country[Coun_codes[i]] = most_viewed_by_country.pop(input_countries[i])

# %%
#  
country_name_covert = {'marshall islands': 'us',
 'taiwan': 'tw',
 'new zealand': 'nz',
 'el salvador': 'sv',
 'macau': 'mo',
 'syria': 'sy',
 'vatican city': 'va',
 'korea, north': 'kp',
 'cayman islands': 'gb',
 'dominican republic': 'do',
 'united states': 'us',
 'burkina faso': 'bf',
 'kosovo': 'al',
 'san marino': 'sm',
 'saint lucia': '',
 'burma': 'mm',
 'côte d’ivoire': 'fr',
 'south sudan': '',
 'sri lanka': 'lk',
 'isle of man': '',
 'venezuela': 've',
 'south africa': 'za',
 'laos': 'la',
 'united kingdom': 'gb',
 'vietnam': 'vn',
 'bosnia and herzegovina': 'ba',
 'korea, south': 'kr',
 'trinidad and tobago': '',
 'iran': 'ir',
 'french polynesia': 'fr',
 'saint vincent and the grenadines': '',
 'moldova': 'md',
 'french guiana': 'gf',
 'sierra leone': 'sl',
 'russia': 'ru',
 'bolivia': 'bo',
 'saudi arabia': 'sa',
 'solomon islands': '',
 'united arab emirates': 'ae',
 'hong kong': 'hk',
 'bahamas, the': '',
 'swaziland': 'sz',
 'reunion': 're',
 'timor-leste': 'tl',
 'macedonia': 'mk',
 'costa rica': 'cr',
 'faroe islands': 'dk',
 'puerto rico': 'pr',
 'tanzania': 'tz',
 'brunei': 'bn'}

# %%
for i in country_name_covert:
     if i in most_viewed_by_country:
            if len(country_name_covert[i]) == 2:
                most_viewed_by_country[country_name_covert[i]] = most_viewed_by_country.pop(i)
            else:
                # Removed the country name which can't find country code  
                print("Unknown country code: " + str(i)) 
                most_viewed_by_country.pop(i)
            
most_viewed_by_country
# Out:
# Unknown country code: saint lucia
# Unknown country code: south sudan
# Unknown country code: isle of man
# Unknown country code: trinidad and tobago
# Unknown country code: saint vincent and the grenadines
# Unknown country code: solomon islands
# Unknown country code: bahamas, the
# {'qa': {'Death Note': 9.53},
#  'hu': {'Death Note': 8.7},
#  'ec': {'Death Note': 8.88},
#  'bb': {'Vampire Knight': 7.25},
#  'au': {'Death Note': 8.59},
#  'ge': {'Death Note': 8.74},
#  'bh': {'Death Note': 9.25},
#  'ng': {'Bleach': 7.56},
#  'sk': {'Death Note': 8.7},
#  'ee': {'Death Note': 8.85},
#  'al': {'Orange': 7.0},
#  'mv': {'One Piece': 8.33},
#  'jm': {'Naruto': 8.07},
#  'ga': {'Chobits': 7.0},
#  'ml': {'Death Note': 9.0},
#  'id': {'Sword Art Online': 8.23},
#  'th': {'Toradora!': 8.6},
#  'my': {'Angel Beats!': 8.73},
#  'br': {'Death Note': 8.75},
#  'lr': {'Fullmetal Alchemist': 9.0},
#  'gt': {'Death Note': 8.75},
#  'cn': {'Code Geass: Hangyaku no Lelouch R2': 9.02},
#  'ar': {'Death Note': 8.58},
#  'si': {'Death Note': 8.93},
#  'ma': {'Death Note': 9.42},
#  'aw': {'Fairy Tail': 8.14},
#  'uz': {'Death Note': 7.86},
#  'es': {'Death Note': 8.54},
#  'jo': {'Death Note': 8.74},
#  'az': {'Death Note': 8.88},
#  'dj': {'Psycho-Pass': 8.0},
#  'dk': {'Naruto': 7.6},
#  'se': {'Death Note': 8.56},
#  'kz': {'Death Note': 8.81},
#  'gu': {'Mayo Chiki!': 7.62},
#  'dz': {'Shingeki no Kyojin': 9.26},
#  'kh': {'Shingeki no Kyojin': 9.2},
#  'fi': {'Death Note': 8.56},
#  'sn': {'High School DxD': 7.0},
#  'is': {'Death Note': 8.8},
#  'ad': {'Death Note': 8.75},
#  'mt': {'Death Note': 8.83},
#  'ca': {'Death Note': 8.61},
#  'ao': {'Elfen Lied': 8.2},
#  'so': {'Zoids': 10.0},
#  'jp': {'Death Note': 8.72},
#  'eg': {'Death Note': 9.18},
#  'mg': {'Death Note': 8.67},
#  'sr': {'Naruto': 8.75},
#  'nl': {'Death Note': 8.76},
#  'tg': {'Majo no Takkyuubin': 1.0},
#  'bm': {'Minami-ke': 8.0},
#  'cu': {'Neon Genesis Evangelion': 7.67},
#  'mq': {'Aldnoah.Zero': 7.5},
#  'me': {'Death Note': 9.13},
#  'it': {'Death Note': 8.37},
#  'ua': {'Death Note': 8.63},
#  'py': {'Death Note': 9.0},
#  'ws': {'Busou Renkin': 6.0},
#  'ph': {'Toradora!': 8.85},
#  'fj': {'Sword Art Online': 7.38},
#  'mn': {'Death Note': 9.0},
#  'mz': {'High School DxD': 5.5},
#  'na': {'Chobits': 7.0},
#  'pe': {'Death Note': 8.85},
#  'cy': {'Death Note': 9.53},
#  'cl': {'Death Note': 8.39},
#  'bd': {'Death Note': 9.18},
#  'hr': {'Death Note': 9.02},
#  'be': {'Death Note': 8.66},
#  'lu': {'Elfen Lied': 7.71},
#  'in': {'Death Note': 9.14},
#  'pt': {'Death Note': 8.92},
#  'tr': {'Death Note': 9.0},
#  'gh': {'Death Note': 7.75},
#  'lb': {'Death Note': 8.79},
#  'mr': {'Fullmetal Alchemist': 9.0},
#  'cz': {'Death Note': 8.73},
#  'ne': {'Bleach': 7.56},
#  'lv': {'Death Note': 9.06},
#  'pk': {'Death Note': 9.14},
#  'tn': {'Death Note': 9.25},
#  'lt': {'Death Note': 9.19},
#  'kg': {'Minami-ke': 7.0},
#  'ro': {'Death Note': 9.28},
#  'bz': {'Shingeki no Kyojin': 9.4},
#  'ki': {'JoJo no Kimyou na Bouken: Stardust Crusaders 2nd Season': 9.0},
#  'co': {'Death Note': 8.85},
#  'je': {'Suzumiya Haruhi no Yuuutsu': 8.75},
#  'cw': {'Bleach': 10.0},
#  'il': {'Death Note': 8.87},
#  'at': {'Death Note': 8.91},
#  'iq': {'Death Note': 8.95},
#  'mc': {"Wolf's Rain": 8.0},
#  'hn': {'Death Note': 9.13},
#  'ye': {'Baka to Test to Shoukanjuu': 7.86},
#  'ch': {'Death Note': 8.53},
#  'by': {'Death Note': 8.5},
#  'gr': {'Death Note': 8.95},
#  'pa': {'Death Note': 9.19},
#  'ie': {'Death Note': 8.64},
#  'rs': {'Death Note': 8.94},
#  'gy': {'Sword Art Online': 7.14},
#  'ke': {'Bleach': 8.33},
#  'no': {'Death Note': 8.71},
#  'pl': {'Death Note': 8.85},
#  'zw': {'Campione!: Matsurowanu Kamigami to Kamigoroshi no Maou': 6.33},
#  'ht': {'Sen to Chihiro no Kamikakushi': 7.5},
#  'mu': {'Death Note': 9.42},
#  'fr': {'Break Blade': 4.0},
#  'ni': {'Death Note': 9.1},
#  'gl': {'Baka to Test to Shoukanjuu': 7.43},
#  'bg': {'Death Note': 9.24},
#  'sd': {'Shingeki no Kyojin': 8.0},
#  'mx': {'Death Note': 8.84},
#  'sg': {'Toradora!': 8.49},
#  'uy': {'Death Note': 8.6},
#  'ly': {'Death Note': 9.42},
#  'ug': {'Sword Art Online': 6.5},
#  'np': {'Sword Art Online': 8.23},
#  'li': {'JoJo no Kimyou na Bouken: Stardust Crusaders 2nd Season': 10.0},
#  'am': {'Sen to Chihiro no Kamikakushi': 8.17},
#  'gd': {'Bleach': 9.5},
#  'bt': {'Naruto': 10.0},
#  'dm': {'Death Note': 9.24},
#  'de': {'Death Note': 8.85},
#  'bw': {'Naruto': 8.0},
#  'om': {'Death Note': 9.43},
#  'kw': {'Death Note': 9.18},
#  'tw': {'Code Geass: Hangyaku no Lelouch': 9.12},
#  'nz': {'Death Note': 8.52},
#  'sv': {'Death Note': 9.0},
#  'mo': {'Shingeki no Kyojin': 8.75},
#  'sy': {'Death Note': 9.26},
#  'va': {'High School DxD': 7.0},
#  'kp': {'Death Note': 6.75},
#  'gb': {'Death Note': 8.7},
#  'do': {'Death Note': 9.19},
#  'us': {'Death Note': 8.55},
#  'bf': {'Bleach': 6.67},
#  'sm': {'JoJo no Kimyou na Bouken: Stardust Crusaders 2nd Season': 8.0},
#  'mm': {'Clannad': 8.4},
#  'lk': {'Death Note': 8.75},
#  've': {'Death Note': 8.69},
#  'za': {'Death Note': 8.63},
#  'la': {'Hyouka: Motsubeki Mono wa': 8.5},
#  'vn': {'Angel Beats!': 8.59},
#  'ba': {'Death Note': 9.22},
#  'kr': {'Death Note': 8.44},
#  'ir': {'Death Note': 8.59},
#  'md': {'Death Note': 8.95},
#  'gf': {'Boku no Hero Academia 2nd Season: Hero Note': 7.0},
#  'sl': {'Tokyo Mew Mew': 6.0},
#  'ru': {'Death Note': 8.28},
#  'bo': {'Death Note': 8.21},
#  'sa': {'Death Note': 9.22},
#  'ae': {'Death Note': 8.91},
#  'hk': {'Angel Beats!': 8.8},
#  'sz': {'Chobits': 10.0},
#  're': {'Dragon Ball Z Movie 14: Kami to Kami': 10.0},
#  'tl': {'Bakuten Shoot Beyblade 2002': 7.0},
#  'mk': {'Death Note': 9.12},
#  'cr': {'Death Note': 8.89},
#  'pr': {'Death Note': 8.98},
#  'tz': {'Boku wa Tomodachi ga Sukunai': 7.0},
#  'bn': {'Toradora!': 8.53}}

# %%
for i in most_viewed_by_country:
    print(list(most_viewed_by_country[i].values())[0])
# Out:
# 9.53
# 8.7
# 8.88
# 7.25
# 8.59
# 8.74
# 9.25
# 7.56
# 8.7
# 8.85
# 7.0
# 8.33
# 8.07
# 7.0
# 9.0
# 8.23
# 8.6
# 8.73
# 8.75
# 9.0
# 8.75
# 9.02
# 8.58
# 8.93
# 9.42
# 8.14
# 7.86
# 8.54
# 8.74
# 8.88
# 8.0
# 7.6
# 8.56
# 8.81
# 7.62
# 9.26
# 9.2
# 8.56
# 7.0
# 8.8
# 8.75
# 8.83
# 8.61
# 8.2
# 10.0
# 8.72
# 9.18
# 8.67
# 8.75
# 8.76
# 1.0
# 8.0
# 7.67
# 7.5
# 9.13
# 8.37
# 8.63
# 9.0
# 6.0
# 8.85
# 7.38
# 9.0
# 5.5
# 7.0
# 8.85
# 9.53
# 8.39
# 9.18
# 9.02
# 8.66
# 7.71
# 9.14
# 8.92
# 9.0
# 7.75
# 8.79
# 9.0
# 8.73
# 7.56
# 9.06
# 9.14
# 9.25
# 9.19
# 7.0
# 9.28
# 9.4
# 9.0
# 8.85
# 8.75
# 10.0
# 8.87
# 8.91
# 8.95
# 8.0
# 9.13
# 7.86
# 8.53
# 8.5
# 8.95
# 9.19
# 8.64
# 8.94
# 7.14
# 8.33
# 8.71
# 8.85
# 6.33
# 7.5
# 9.42
# 4.0
# 9.1
# 7.43
# 9.24
# 8.0
# 8.84
# 8.49
# 8.6
# 9.42
# 6.5
# 8.23
# 10.0
# 8.17
# 9.5
# 10.0
# 9.24
# 8.85
# 8.0
# 9.43
# 9.18
# 9.12
# 8.52
# 9.0
# 8.75
# 9.26
# 7.0
# 6.75
# 8.7
# 9.19
# 8.55
# 6.67
# 8.0
# 8.4
# 8.75
# 8.69
# 8.63
# 8.5
# 8.59
# 9.22
# 8.44
# 8.59
# 8.95
# 7.0
# 6.0
# 8.28
# 8.21
# 9.22
# 8.91
# 8.8
# 10.0
# 10.0
# 7.0
# 9.12
# 8.89
# 8.98
# 7.0
# 8.53

# %%
country_by_animes = {}
for i in most_viewed_by_country:
    if list(most_viewed_by_country[i].keys())[0] in country_by_animes:
        res = country_by_animes[list(most_viewed_by_country[i].keys())[0]]
        res[i] = list(most_viewed_by_country[i].values())[0]
    else:
        res={}
        res[i] = list(most_viewed_by_country[i].values())[0]
        country_by_animes[list(most_viewed_by_country[i].keys())[0]] = res
    
# Sort country_by_animes dictionary by values
country_by_animes = {k: v for k, v in sorted(country_by_animes.items(), key=lambda item: len(item[1]), reverse=True)}

# %%
country_by_animes
# Out:
# {'Death Note': {'qa': 9.53,
#   'hu': 8.7,
#   'ec': 8.88,
#   'au': 8.59,
#   'ge': 8.74,
#   'bh': 9.25,
#   'sk': 8.7,
#   'ee': 8.85,
#   'ml': 9.0,
#   'br': 8.75,
#   'gt': 8.75,
#   'ar': 8.58,
#   'si': 8.93,
#   'ma': 9.42,
#   'uz': 7.86,
#   'es': 8.54,
#   'jo': 8.74,
#   'az': 8.88,
#   'se': 8.56,
#   'kz': 8.81,
#   'fi': 8.56,
#   'is': 8.8,
#   'ad': 8.75,
#   'mt': 8.83,
#   'ca': 8.61,
#   'jp': 8.72,
#   'eg': 9.18,
#   'mg': 8.67,
#   'nl': 8.76,
#   'me': 9.13,
#   'it': 8.37,
#   'ua': 8.63,
#   'py': 9.0,
#   'mn': 9.0,
#   'pe': 8.85,
#   'cy': 9.53,
#   'cl': 8.39,
#   'bd': 9.18,
#   'hr': 9.02,
#   'be': 8.66,
#   'in': 9.14,
#   'pt': 8.92,
#   'tr': 9.0,
#   'gh': 7.75,
#   'lb': 8.79,
#   'cz': 8.73,
#   'lv': 9.06,
#   'pk': 9.14,
#   'tn': 9.25,
#   'lt': 9.19,
#   'ro': 9.28,
#   'co': 8.85,
#   'il': 8.87,
#   'at': 8.91,
#   'iq': 8.95,
#   'hn': 9.13,
#   'ch': 8.53,
#   'by': 8.5,
#   'gr': 8.95,
#   'pa': 9.19,
#   'ie': 8.64,
#   'rs': 8.94,
#   'no': 8.71,
#   'pl': 8.85,
#   'mu': 9.42,
#   'ni': 9.1,
#   'bg': 9.24,
#   'mx': 8.84,
#   'uy': 8.6,
#   'ly': 9.42,
#   'dm': 9.24,
#   'de': 8.85,
#   'om': 9.43,
#   'kw': 9.18,
#   'nz': 8.52,
#   'sv': 9.0,
#   'sy': 9.26,
#   'kp': 6.75,
#   'gb': 8.7,
#   'do': 9.19,
#   'us': 8.55,
#   'lk': 8.75,
#   've': 8.69,
#   'za': 8.63,
#   'ba': 9.22,
#   'kr': 8.44,
#   'ir': 8.59,
#   'md': 8.95,
#   'ru': 8.28,
#   'bo': 8.21,
#   'sa': 9.22,
#   'ae': 8.91,
#   'mk': 9.12,
#   'cr': 8.89,
#   'pr': 8.98},
#  'Bleach': {'ng': 7.56,
#   'ne': 7.56,
#   'cw': 10.0,
#   'ke': 8.33,
#   'gd': 9.5,
#   'bf': 6.67},
#  'Naruto': {'jm': 8.07, 'dk': 7.6, 'sr': 8.75, 'bt': 10.0, 'bw': 8.0},
#  'Sword Art Online': {'id': 8.23,
#   'fj': 7.38,
#   'gy': 7.14,
#   'ug': 6.5,
#   'np': 8.23},
#  'Shingeki no Kyojin': {'dz': 9.26,
#   'kh': 9.2,
#   'bz': 9.4,
#   'sd': 8.0,
#   'mo': 8.75},
#  'Toradora!': {'th': 8.6, 'ph': 8.85, 'sg': 8.49, 'bn': 8.53},
#  'Chobits': {'ga': 7.0, 'na': 7.0, 'sz': 10.0},
#  'Angel Beats!': {'my': 8.73, 'vn': 8.59, 'hk': 8.8},
#  'High School DxD': {'sn': 7.0, 'mz': 5.5, 'va': 7.0},
#  'JoJo no Kimyou na Bouken: Stardust Crusaders 2nd Season': {'ki': 9.0,
#   'li': 10.0,
#   'sm': 8.0},
#  'Fullmetal Alchemist': {'lr': 9.0, 'mr': 9.0},
#  'Elfen Lied': {'ao': 8.2, 'lu': 7.71},
#  'Minami-ke': {'bm': 8.0, 'kg': 7.0},
#  'Baka to Test to Shoukanjuu': {'ye': 7.86, 'gl': 7.43},
#  'Sen to Chihiro no Kamikakushi': {'ht': 7.5, 'am': 8.17},
#  'Vampire Knight': {'bb': 7.25},
#  'Orange': {'al': 7.0},
#  'One Piece': {'mv': 8.33},
#  'Code Geass: Hangyaku no Lelouch R2': {'cn': 9.02},
#  'Fairy Tail': {'aw': 8.14},
#  'Psycho-Pass': {'dj': 8.0},
#  'Mayo Chiki!': {'gu': 7.62},
#  'Zoids': {'so': 10.0},
#  'Majo no Takkyuubin': {'tg': 1.0},
#  'Neon Genesis Evangelion': {'cu': 7.67},
#  'Aldnoah.Zero': {'mq': 7.5},
#  'Busou Renkin': {'ws': 6.0},
#  'Suzumiya Haruhi no Yuuutsu': {'je': 8.75},
#  "Wolf's Rain": {'mc': 8.0},
#  'Campione!: Matsurowanu Kamigami to Kamigoroshi no Maou': {'zw': 6.33},
#  'Break Blade': {'fr': 4.0},
#  'Code Geass: Hangyaku no Lelouch': {'tw': 9.12},
#  'Clannad': {'mm': 8.4},
#  'Hyouka: Motsubeki Mono wa': {'la': 8.5},
#  'Boku no Hero Academia 2nd Season: Hero Note': {'gf': 7.0},
#  'Tokyo Mew Mew': {'sl': 6.0},
#  'Dragon Ball Z Movie 14: Kami to Kami': {'re': 10.0},
#  'Bakuten Shoot Beyblade 2002': {'tl': 7.0},
#  'Boku wa Tomodachi ga Sukunai': {'tz': 7.0}}

# %%
# import pygal.maps
# import pygal_maps_world.maps
# from pygal.style import Style
custome_style = Style(legend_font_size = 5, )
worldmap = pygal_maps_world.maps.World(style = custome_style)

  
# set the title of the map 
worldmap.title = 'The most popular anime in each country and its score '
   

for i in country_by_animes:

    worldmap.add(i,country_by_animes[i]) 

worldmap.render_in_browser()
# Out:
# file:///var/folders/_y/9wzsy3zn0mb6k84x6x2csywc0000gn/T/tmpqf2vog9g.html
